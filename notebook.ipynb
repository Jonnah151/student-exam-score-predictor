# %%
import pandas as pd
df = pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include="object")
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
categorical_cols = ["gender", "part_time_job", "diet_quality","parental_education_level", "internet_quality","extracurricular_participation"]

# %%
for col in categorical_cols:
    print(f"value counts for {col}: \n {df[col].value_counts()}")
# Out:
# value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='str')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data = df, x = feature, y = "exam_score" )
    plt.title(f"{feature} vs Exam score")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data=df, x=col, y="exam_score")
    plt.title(f"Exam score by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='str')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day", "attendance_percentage", "sleep_hours", "mental_health_rating", "part_time_job"]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 995                  2.6                   77.0          7.5
# 996                  2.9                   86.0          6.8
# 997                  3.0                   61.9          6.5
# 998                  5.4                  100.0          7.6
# 999                  4.3                   89.4          7.1
#
#      mental_health_rating part_time_job  exam_score
# 0                       8            No        56.2
# 1                       8            No       100.0
# 2                       1            No        34.3
# 3                       1            No        26.8
# 4                       1            No        66.4
# ..                    ...           ...         ...
# 995                     6            No        76.1
# 996                     6           Yes        65.9
# 997                     9            No        64.4
# 998                     1           Yes        69.7
# 999                     8            No        74.9
#
# [909 rows x 6 columns]

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 995                  2.6                   77.0          7.5
# 996                  2.9                   86.0          6.8
# 997                  3.0                   61.9          6.5
# 998                  5.4                  100.0          7.6
# 999                  4.3                   89.4          7.1
#
#      mental_health_rating  part_time_job  exam_score
# 0                       8              0        56.2
# 1                       8              0       100.0
# 2                       1              0        34.3
# 3                       1              0        26.8
# 4                       1              0        66.4
# ..                    ...            ...         ...
# 995                     6              0        76.1
# 996                     6              1        65.9
# 997                     9              0        64.4
# 998                     1              1        69.7
# 999                     8              0        74.9
#
# [909 rows x 6 columns]

# %%
x = df_model[features]

# %%
y = df_model[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models={
    "LinearRegression" : {
        "model" : LinearRegression(),
        "params" : {}
    },
    "DecisionTree" : {
        "model" : DecisionTreeRegressor(),
        "params" : {"max_depth":[3,5,10], "min_samples_split":[2,5]}
    },
    "RandomForest" : {
        "model" : RandomForestRegressor(),
        "params" : {"n_estimators":[50,100], "max_depth":[5,10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training{name }")

    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(x_train, y_train)
    y_pred = grid.predict(x_test)
    rmse= np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# TrainingLinearRegression
# TrainingDecisionTree
# TrainingRandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.497144248884678),
#   'r2': 0.8146343506064646},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': np.float64(8.146032379591018),
#   'r2': 0.7811584474921808},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': np.float64(7.656837487982506),
#   'r2': 0.806653470025662}]

# %%
result_df = pd.DataFrame(best_models)

# %%
result_df.sort_values(by ="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.497144
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.656837
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.146032
#
#          r2
# 0  0.814634
# 2  0.806653
# 1  0.781158

# %%
import joblib

best_row = result_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   7.497144
# r2                     0.814634
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(x,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(x_test)
# Out:
# array([ 65.81297953,  79.37860514,  63.04843369,  54.12381522,
#         65.73770789,  85.05701304,  62.92406585,  64.97418345,
#         44.85583341,  85.9407813 ,  71.9069882 ,  76.90551635,
#         54.84649087,  57.45595147,  83.47702877,  72.17523691,
#         55.02624368,  77.1562697 ,  81.17073179, 102.15537878,
#         80.14418379,  54.28921371,  74.79642259,  91.52584331,
#         69.31005922,  84.45415703,  94.48143692,  63.74810186,
#         54.26161987,  73.87388264,  73.76225891,  38.72620623,
#         74.7216201 ,  76.9384696 ,  53.21270007,  90.35284716,
#         75.00352966,  89.92801771,  85.07977392,  77.42086604,
#         80.04701348,  99.38541188,  56.4052808 ,  68.10932257,
#         71.14315062,  54.04532213, 104.58685302,  70.31885498,
#         52.76981731,  76.53481528,  62.79878985,  74.3087117 ,
#         80.12262938,  93.96567609,  63.09414629,  75.5095826 ,
#         60.44639729,  99.00015462,  67.04794846,  75.58766803,
#         81.85562938,  83.39081928,  93.29678994,  55.7323605 ,
#         80.37605908,  83.02517528,  63.64137371,  79.7513049 ,
#         81.73266078,  72.64278476,  58.38827329,  65.24574029,
#         94.97908174, 103.39848608,  82.57292072,  81.64018775,
#         48.56143345,  70.83486134,  93.907731  , 105.00242074,
#         46.52666247,  56.24321262,  73.66672527,  57.55284809,
#         80.50391617,  46.7757078 ,  55.05974475, 105.61559246,
#         45.70477712,  48.2945095 ,  89.8219083 ,  78.93841603,
#         62.66539553,  85.58995874,  65.24858471,  80.25838196,
#         85.23484959,  80.61992577,  50.15515284,  85.35394269,
#         69.18028217,  62.67344973,  61.47538447,  95.41329797,
#         50.57237348,  52.63399438,  65.04552732,  57.44126378,
#         73.63843002,  54.52840609,  81.11484092,  73.73470842,
#         52.84828921,  74.30904731,  88.24077353,  80.80740576,
#         71.00132175,  68.04815179,  78.70663792,  54.1809859 ,
#         53.96667875,  55.45149562,  70.64707086,  53.98710733,
#         61.2642645 ,  61.89130361,  46.24083769,  78.14942594,
#         89.69195799,  40.22731221,  88.8343056 ,  76.75958523,
#         97.86319106,  61.88623029,  56.50647088, 115.32425793,
#         41.50768325,  62.76704043,  86.51178448,  68.00488232,
#         68.38334944,  81.50258474,  60.91996362,  69.44137515,
#         95.80735843,  86.85962666,  62.717919  ,  93.9348698 ,
#         70.63722799,  65.54214455,  66.70036983,  64.69940863,
#         76.36598796,  59.38276315,  59.41323383,  76.48969124,
#         77.38615468,  84.71786767,  58.60039915, 102.20707529,
#         74.53698275,  64.13092859,  67.1142276 ,  46.42355805,
#         65.58871377,  58.48066121,  63.56874464,  74.44479129,
#         67.22882072,  47.10026421,  79.59311223,  49.85660749,
#         93.5987542 ,  67.24642978, 101.05772654,  70.06256803,
#         70.20854282,  74.18329974,  92.59169846,  58.71341382,
#         87.78875123,  66.0866954 ])
